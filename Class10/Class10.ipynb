# %% [markdown]
# # Plotting with Matplotlib

# %% [markdown]
# ## Initial Plots

# %%
x=np.linspace(0,2,100)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')


plt.title("Simple Plot")
plt.legend()
plt.show()

# %% [markdown]
# ## Formatting style

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16],'g--.')
plt.axis([0,6,0,20])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-aa6257f2e4da> in <module>
# ----> 1 plt.plot([1,2,3,4], [1,4,9,16],'g--.10')
#       2 plt.axis([0,6,0,20])
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     364         ret = []
#     365         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 366             linestyle, marker, color = _process_plot_format(tup[-1])
#     367             tup = tup[:-1]
#     368         elif len(tup) == 3:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_plot_format(fmt)
#      89             if marker is not None:
#      90                 raise ValueError(
# ---> 91                     'Illegal format string "%s"; two marker symbols' % fmt)
#      92             marker = c
#      93             i += 1
#
# ValueError: Illegal format string "g--.10"; two marker symbols

# %%
plt.plot([1,2,3,4], [1,4,9,16],'g-x')
plt.axis([0,6,0,20])
plt.show()

# %%
import numpy as np
# evenly sampled time at 200ms intervals 
t=np.arange(0.,5.,0.2)
# red dashes, blue squares and green triangles
plt.plot(t, t,'r--', t, t**2,'bs', t, t**3,'g^')
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16],color="green",linestyle="--",marker=".",markersize=10)
plt.axis([0,6,0,20])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(50)
y=x+10*np.random.randn(50)
color=np.random.randint(0,50,50)
size=200*np.random.randn(50)
plt.scatter(x,y, c=color, s=size)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ## Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)
plt.plot(x, y)
plt.title('A single plot')
plt.show()

# %%
fig, axs = plt.subplots(2,2,figsize=(10,10))
axs[0,1].plot(x, y)
axs[0,0].plot(x, -y)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y)
plt.subplot(1,2,2)
plt.plot(x, -y)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(5,8))
fig.suptitle('Vertically stacked subplots')
ax1.plot(x, y)
ax2.plot(x, -y)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(x, y)
plt.title('Vertically stacked subplots')
plt.subplot(2,1,2)
plt.plot(x, -y)
plt.show()

# %%
fig, axs = plt.subplots(2, 2,figsize=(10,10))

axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0,0]')
axs[0, 1].plot(x, y, 'orange')
axs[0, 1].set_title('Axis [0,1]')
axs[1, 0].plot(x, -y, 'green')
axs[1, 0].set_title('Axis [1,0]')
axs[1, 1].plot(x, -y, 'red')
axs[1, 1].set_title('Axis [1,1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
    
#axs[1,1].set_ylabel('asd')
#axs.flat[1].set(xlabel='aaaa')
# Out:
# AAAAAAAAAAAAAAAA

# %%
axs.flat[3]
# Out:
# <bound method Axes.plot of <matplotlib.axes._subplots.AxesSubplot object at 0x000001ECDE6A56A0>>

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.plot(x, y)
plt.title('Axis [0,0]')
plt.subplot(2,2,2)
plt.plot(x, y, 'orange')
plt.title('Axis [0,1]')
plt.subplot(2,2,3)
plt.plot(x, -y, 'green')
plt.title('Axis [1,0]')
plt.subplot(2,2,4)
plt.plot(x, -y, 'red')
plt.title('Axis [1,1]')
plt.show()

# %% [markdown]
# ## Several figures

# %%
import matplotlib.pyplot as plt
plt.figure(1)      # the first figure
plt.subplot(211)   # the first subplot in the first figure
plt.plot([1,2,3])
plt.subplot(212)   # the second subplot in the first figure
plt.plot([4,5,6])

plt.figure(2)      # a second figure
plt.plot([4,5,6])  # creates a subplot(111) by default

plt.figure(1)      # figure 1 current; subplot(212) still current
plt.subplot(211)   # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3')# subplot 211 title
# Out:
# C:\Users\jorge\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':
# Text(0.5, 1.0, 'Easy as 1, 2, 3')

# %% [markdown]
# ## Add Text

# %%
mu, sigma=100,15
x=mu+sigma*np.random.randn(10000)# the histogram of the data
plt.hist(x,50, density=1, facecolor='g', alpha=0.75)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')

plt.text(60,.025,r'$\mu=100$,$\sigma=15$')
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Annotation

# %%
t=np.arange(0.0,5.0,0.01)
s=np.cos(2*np.pi*t)

plt.plot(t, s, lw=2)
plt.ylim(-2,2)

plt.annotate('local max', xy=(2,1), xytext=(3,1.5),arrowprops=dict(facecolor='yellow', shrink=0.05))

plt.show()

# %% [markdown]
# ## Axes Scales

# %%
y=range(1,10000)
x=range(1,10000)
# plot with various axes scales
plt.figure(figsize=(5,10))


# linear
plt.subplot(211)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(212)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


plt.show()

# %% [markdown]
# ## Custom Legend

# %%
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
plt.plot([2,2,2], label="test3")
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.legend( bbox_to_anchor=(0,0.15,1,1),ncol=3,mode="expand")
plt.show()

# %%
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.show()

# %% [markdown]
# # Char Types

# %% [markdown]
# ## Line plots

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

plt.plot(t, s)
plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('Example of Line Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(50)
y=x+10*np.random.randn(50)
color=np.random.randint(0,50,50)
size=200*np.random.randn(50)
plt.scatter(x,y, c=color, s=size)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ## Histograms

# %% [markdown]
# #### num_bins= 50

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

mu = 100    # mean of distribution
sigma = 15  # standard deviation of distribution
num_bins = 50
x = mu + sigma * np.random.randn(500)

n, bins, patches =plt.hist(x, num_bins, density=1)

# actual gaussian curve
gaussian = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * ((bins - mu)/ sigma )**2))

plt.plot(bins, gaussian, '--r')
plt.xlabel('Bins')
plt.ylabel('Probability density')
plt.title(r'Histogram: $\mu=100$, $\sigma=15$')
plt.show()

# %%
x
# Out:
# array([102.70505985,  73.80995496,  99.95815847,  90.61737067,
#         85.07388892,  61.91394558, 115.00924355, 133.9766432 ,
#         92.61017695,  92.26704127, 105.76780323, 100.67719355,
#         99.52969503, 100.51525777,  89.93326761,  95.02445689,
#         91.88982222,  99.67728115, 108.31755688, 106.44303666,
#         90.86704509, 106.30753209, 119.95051164, 103.58077744,
#        124.20349456, 119.66842284, 108.72176825, 107.05965181,
#         81.8681194 , 102.8886875 , 110.47493966, 102.4500982 ,
#        105.64562491,  83.42745294, 118.51597183,  93.46929995,
#         97.44035244, 118.13759589, 115.97670766, 110.97627021,
#         99.28390179, 117.17800606,  86.66874169, 103.09563029,
#         75.02179296, 111.28312423, 101.19367376,  75.57189888,
#        115.67415738,  87.70592199,  84.05285269,  93.30010335,
#         97.34669031, 108.7049647 ,  99.21590111, 107.45275895,
#        100.6330129 ,  90.62001544,  81.42701869, 111.02068154,
#        107.50498176,  96.84603465, 115.24136835,  66.73666696,
#         95.9350513 ,  96.17056284,  94.33757326, 103.02511662,
#         86.97103557, 106.91625936,  99.70479915, 128.80420529,
#         92.0997717 , 113.99254953, 115.67936268,  83.24810621,
#        132.12214782,  79.61904779, 112.76206059, 120.81422996,
#        109.29275665, 103.22142558, 111.4871251 ,  97.01568332,
#        109.74381793, 117.93678597,  68.88205665, 112.44917382,
#         67.64756538,  59.6800359 , 102.57651686,  97.0408011 ,
#        103.18945984,  90.92812651, 122.77981307,  92.76841923,
#        107.4486914 ,  89.69660467, 127.26579754,  89.37679688,
#        100.78857566,  98.77625945,  92.01691854,  97.61732476,
#        124.9172556 , 104.85042721,  99.96487842,  89.15079721,
#         97.47861999,  78.21491763,  99.4579148 ,  95.47618804,
#         90.33938185, 109.43814783,  97.85343778,  52.9217265 ,
#         86.71084811,  63.55561547, 117.19885217,  78.06478159,
#         85.40645539, 111.1303282 ,  74.27675907, 118.75688712,
#         59.58850525,  89.29673563, 109.21889826, 113.7211656 ,
#         83.73064965, 123.8263437 , 107.61345234, 124.48950989,
#         85.11637416,  87.97056155, 126.1813629 , 106.71587118,
#        120.80663104, 108.92435069,  80.38262441, 112.57460988,
#        103.71234368, 103.48071858, 100.99991354,  91.9822739 ,
#         80.76666663,  82.31940523,  86.58161819, 115.03371066,
#         95.29205858,  85.07028665,  92.66566042, 104.44041364,
#         94.8842372 ,  69.21906648,  92.67496834, 101.70695038,
#         82.66744124,  79.07974501,  96.86095913,  98.5115924 ,
#         92.97335053,  94.76432017,  88.68433617, 107.37253091,
#        102.94955689, 111.84084487, 104.1556648 , 101.80698598,
#         79.72111864,  74.28290096,  81.84206838,  82.79092951,
#         81.48979538, 111.83421558, 112.25763069, 104.57127006,
#         77.95693791,  74.69175811,  89.36825723,  88.55832899,
#         77.21074074, 104.3637303 , 101.6808126 , 111.24613272,
#        113.09117172,  98.70795831,  74.7871732 , 116.54478917,
#         96.0233062 , 107.81367088,  79.91450656, 108.3815429 ,
#        101.42747115,  90.13891626,  89.70895022,  98.40631962,
#        122.19276848, 105.51378389, 100.7869295 ,  84.80217958,
#        112.04870357, 107.50551887, 107.89910808, 102.17809992,
#        121.37462246,  93.86372927, 130.29762697,  96.35051455,
#        102.55202817,  96.81857262, 103.67728036, 116.42624532,
#        106.24080463, 102.53757031, 104.80832844, 132.8558642 ,
#        125.01013271, 140.7422848 ,  94.43456681,  96.00694928,
#        121.70101536, 118.34535121, 103.86027266, 124.19415133,
#        113.10048417,  99.24295391, 109.43714186,  92.51721566,
#         81.80812477, 103.12387897, 101.43638591,  99.64869567,
#        118.36251731,  98.27653784, 122.7318119 ,  94.99495356,
#         90.3093485 ,  90.11007292,  94.22360654,  99.53920283,
#        105.4380872 , 102.57967423,  99.8638587 , 105.41317326,
#         85.04375382, 106.58563507, 104.61265062,  90.10044846,
#        106.08854587, 108.98001575,  94.32327451, 102.66605589,
#         91.33202501, 132.85515352, 115.02212114,  76.22305851,
#        104.3312842 , 119.63343391,  98.48304334, 115.47594012,
#         76.03087807, 112.15098277, 106.31419858, 108.10907933,
#        122.28153423, 113.93024144, 104.74758128, 106.54632094,
#        104.76306049,  93.06000743, 117.00171093,  82.08898666,
#        107.7349094 , 118.94584093, 111.12634324,  99.09272266,
#         87.87510545,  98.87678918,  73.92241016,  90.43889292,
#        106.52492585,  89.98691931, 100.03598076,  66.77716846,
#        100.99146156,  98.95121707, 106.56493635,  74.47590336,
#        116.5296589 , 105.20658873,  82.62187425,  98.82551589,
#         92.73030654, 105.71773036, 109.04685195,  86.63572765,
#         88.13165083,  63.20186287,  91.83269201, 110.63618105,
#         97.92192308,  78.91925654, 129.80286744, 100.8180686 ,
#         82.75323766,  85.54573042, 110.07711427, 102.91318328,
#         69.94391879, 117.44227236,  78.73571096, 110.66074011,
#         98.26260209,  99.26638902,  86.19659233,  90.57571017,
#        120.03307533, 118.9750194 , 104.31699747, 103.81881223,
#        116.34845389,  91.95628168,  93.47875105, 119.39707904,
#         88.04184214, 116.03112954,  78.63052669, 100.3501154 ,
#         83.23375719, 125.09204177, 106.39595765,  72.78937841,
#         86.11552497, 119.17223384,  89.51442922,  85.22816273,
#         86.18653356,  86.92821492,  87.37104987,  89.39013758,
#         67.07689655, 108.5248094 ,  98.91953718,  97.07131898,
#         56.99819866,  90.40555854, 120.43628629,  97.99809323,
#         84.97324933,  92.65056311, 100.10858289, 120.16191275,
#        116.09266759,  91.00540574, 100.1539798 ,  96.45502602,
#         90.73481745,  87.10605044, 104.54679788, 105.59672634,
#        103.97176517, 101.85899742, 107.5719356 ,  70.30924734,
#        108.99427281,  98.84788679, 104.96427519,  91.18381859,
#         87.1473441 ,  81.10798256, 100.04109585,  95.04173598,
#         97.73885011,  89.06061978, 124.46115492, 114.17671679,
#         76.93414432,  98.60385678,  91.18787599,  67.59524529,
#        100.8722058 , 100.12387288, 113.62323572,  77.97221393,
#         95.70812347, 107.25568036,  99.39917825,  82.02813627,
#        117.30242029, 110.47194722,  82.1075194 , 129.0158239 ,
#        118.80276714,  87.60632938,  90.17893485,  89.03297784,
#        112.17304125,  74.20726595, 117.44628637, 109.51504711,
#         85.47441927, 124.47180344,  98.34265319,  73.5391894 ,
#        123.00211276,  96.755361  , 111.2436859 , 104.14109431,
#         88.55985429,  85.99186828, 103.59414418, 109.65457855,
#         94.75571432, 116.21444498,  70.60620663,  90.79140931,
#         96.47555375, 101.99424435, 122.94730996, 118.63447183,
#        109.99662838, 105.37227522,  77.3259868 , 105.45813242,
#        113.23639678,  77.59429589, 104.00017623,  94.59094839,
#         98.81031379, 116.16674886,  94.05240703, 109.96511406,
#        125.14816601,  73.40854159,  96.14815294,  79.45115612,
#        132.09253095,  96.35518917,  98.70319787,  80.94912289,
#         98.68878992,  98.33949657, 110.3788052 , 118.53269063,
#        108.97536288, 132.52258331, 106.90687474, 116.29805069,
#        103.78804601, 131.86362459, 108.87135693,  86.06027247,
#         95.53313853, 107.87602613, 103.76441394, 116.66391199,
#        130.54949776,  89.69634242, 116.76191627,  76.68378545,
#         96.2233421 , 108.08996543,  96.81866836, 103.93589282,
#        100.64631477,  85.99337452, 130.96237489, 106.07935399,
#         94.45211627,  91.87400946,  93.01930309, 116.13774341,
#         81.89287124, 102.67594645, 105.00182966,  92.35526841,
#         65.86489801,  71.84618246,  91.50859551, 107.70182364,
#         95.88790466,  83.56584652, 100.21262538, 104.44254394,
#        101.42680803,  85.79072033,  95.63384684,  96.69235555,
#        109.42868219,  89.82458814, 120.1207835 ,  93.61477749,
#         85.04765419, 116.4700163 ,  85.77105536,  95.80301824,
#        102.55212032, 106.17570386,  99.1196296 , 117.80382552])

# %% [markdown]
# #### num_bins = 100

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

mu = 100    # mean of distribution
sigma = 15  # standard deviation of distribution
num_bins = 100
x = mu + sigma * np.random.randn(500)

n, bins, patches =plt.hist(x, num_bins, density=1)

# actual gaussian curve
gaussian = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * ((bins - mu)/ sigma )**2))

plt.plot(bins, gaussian, '--r')
plt.xlabel('Bins')
plt.ylabel('Probability density')
plt.title(r'Histogram: $\mu=100$, $\sigma=15$')
plt.show()

# %% [markdown]
# ## Bar charts

# %% [markdown]
# #### Vertical Bar

# %%
import numpy as np
import matplotlib.pyplot as plt

means_men = (20, 35, 30, 35, 27)
means_women = (25, 32, 34, 20, 25)
index = np.arange(len(means_men)) 
 
bar_width = 0.35
opacity = 0.4

plt.bar(index, means_men, bar_width,
                alpha=opacity, color='b',
                label='Men')

plt.bar(index + bar_width, means_women, bar_width,
                alpha=opacity, color='r',
                label='Women')

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(index + bar_width / 2, labels=('A', 'B', 'C', 'D', 'E'))
plt.legend()
plt.show()

# %% [markdown]
# #### Horizontal bar

# %%
import numpy as np
import matplotlib.pyplot as plt

means_men = (20, 35, 30, 35, 27)
means_women = (25, 32, 34, 20, 25)
index = np.arange(len(means_men)) 
 
bar_width = 0.35
opacity = 0.4

plt.barh(index, means_men, bar_width,
                alpha=opacity, color='b',
                label='Men')

plt.barh(index + bar_width, means_women, bar_width,
                alpha=opacity, color='r',
                label='Women')

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.yticks(index + bar_width / 2, labels=('A', 'B', 'C', 'D', 'E'))
plt.legend()
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
import matplotlib.pyplot as plt

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0.1, 0, 0) 

plt.pie(sizes, explode=explode, labels=labels, 
        autopct='%.1f%%',
        shadow=True, startangle=0)

plt.show()

# %% [markdown]
# ## Timeseries (Financial data)

# %% [markdown]
# #### Remember to install datareader if required
#
# If needed go to Anaconda console and run: "conda install pandas-datareader"

# %% [markdown]
# #### Get Financial data using package pandas-datareader

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# Define the instruments to download. We would like to see Apple and Microsoft
tickers = ['AAPL', 'MSFT']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2010-01-01'
end_date =   '2019-01-27'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader(tickers, 'yahoo', start_date, end_date)
df=panel_data.stack()
df.head()
# Out:
# Attributes          Adj Close      Close       High        Low       Open  \
# Date       Symbols
# 2010-01-04 AAPL     26.601469  30.572857  30.642857  30.340000  30.490000
#            MSFT     24.443624  30.950001  31.100000  30.590000  30.620001
# 2010-01-05 AAPL     26.647457  30.625713  30.798571  30.464285  30.657143
#            MSFT     24.451517  30.959999  31.100000  30.639999  30.850000
# 2010-01-06 AAPL     26.223597  30.138571  30.747143  30.107143  30.625713
#
# Attributes               Volume
# Date       Symbols
# 2010-01-04 AAPL     123432400.0
#            MSFT      38409100.0
# 2010-01-05 AAPL     150476200.0
#            MSFT      49749600.0
# 2010-01-06 AAPL     138040000.0

# %% [markdown]
# #### Focus on "Close" stock value, ignore the weekends and fill blank

# %%
# Getting just the adjusted closing prices.
close = panel_data['Close']
print("Data received:", close.shape)
close.head(8)
# Out:
# Data received: (2281, 2)
# Symbols          AAPL       MSFT
# Date
# 2010-01-04  30.572857  30.950001
# 2010-01-05  30.625713  30.959999
# 2010-01-06  30.138571  30.770000
# 2010-01-07  30.082857  30.450001
# 2010-01-08  30.282858  30.660000
# 2010-01-11  30.015715  30.270000
# 2010-01-12  29.674286  30.070000
# 2010-01-13  30.092857  30.350000

# %% [markdown]
# #### Plot Microsfot Close graph

# %%
msft = close.iloc[:]['MSFT']

# %%
# Get the MSFT timeseries. This now returns a Pandas Series object indexed by date.
msft = close.iloc[:]['MSFT']

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_msft = msft.rolling(window=20).mean()
long_rolling_msft  = msft.rolling(window=100).mean()

# Plot everything
plt.figure(figsize=(16,9))

plt.plot(msft.index, msft, label='MSFT')
plt.plot(short_rolling_msft.index, short_rolling_msft, label='20 days rolling',color="red")
plt.plot(long_rolling_msft.index, long_rolling_msft, label='100 days rolling',color="magenta")

plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ## Ploting 3D

# %% [markdown]
# #### Starting 3D

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %% [markdown]
# #### Scatter plot

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.1)

ax.scatter(X, Y, Z,'.',s=0.4)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# #### Wireframe

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.03)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

# %% [markdown]
# #### Surfaces

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.

ax.plot_surface(X, Y, Z, color='r')

plt.show()
